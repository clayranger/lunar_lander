# %%
from sqlalchemy import text
from db_manager_v2 import engine, Base

# Full reset (development only)
with engine.connect() as conn:
    conn.execute(text("DROP SCHEMA public CASCADE;"))
    conn.execute(text("CREATE SCHEMA public;"))
    conn.commit()

# Recreate all tables

Base.metadata.create_all(engine)

print("✅ Database has been fully reset and tables recreated.")
# Out:
# 2026-06-20 17:38:03 | INFO     | Logging initialized. Writing to logs/trades.log
# ✅ Database has been fully reset and tables recreated.

# %%
from dev_setup import full_dev_setup

result = full_dev_setup(public_key="FooAzfN8ThgZEe3LD1oVoD1xzcc8f5D34gac7VqYv1WS")

if result.is_ok:
    print("✅ Setup done!")
else:
    print("❌ Error:", result.error)
# Out:
# 2026-06-20 17:38:04 | INFO     | [SETUP] Starting full development setup...
# 2026-06-20 17:38:04 | INFO     | [SETUP] Database tables created
# 2026-06-20 17:38:04 | INFO     | [SETUP] Default user 'adam' created
# 2026-06-20 17:38:04 | INFO     | [SETUP] Added Platform Coin (So111111...)
# 2026-06-20 17:38:04 | INFO     | [SETUP] Added Stable Coin (EPjFWdd5...)
# 2026-06-20 17:38:04 | INFO     | [0] Added token DtR4D9Ft (decimals=9)
# 2026-06-20 17:38:04 | INFO     | [1] Added token 8bd3PSBp (decimals=9)
# 2026-06-20 17:38:04 | INFO     | [2] Added token 61V8vBaq (decimals=9)
# 2026-06-20 17:38:04 | INFO     | [3] Added token 9PR7nCP9 (decimals=9)
# 2026-06-20 17:38:04 | INFO     | [4] Added token 3B5wuUrM (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [5] Added token Ez3nzG9o (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [6] Added token 4vMsoUT2 (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [7] Added token UXPhBoR3 (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [8] Added token METAewgx (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [9] Added token CaGa7pdd (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [10] Added token CTJf74cT (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [11] Added token 5LafQUrV (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [12] Added token HZ1JovNi (decimals=9)
# 2026-06-20 17:38:05 | INFO     | [13] Added token JUPyiwrY (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [14] Added token MEW1gQWJ (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [15] Added token EKpQGSJt (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [16] Added token rndrizKT (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [17] Added token jtojtome (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [18] Added token 85VBFQZC (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [19] Added token ZEUS1aR7 (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [20] Added token 4k3Dyjzv (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [21] Added token TNSRxcUx (decimals=9)
# 2026-06-20 17:38:06 | INFO     | [22] Added token 7BgBvyjr (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [23] Added token ZBCNpuD7 (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [24] Added token 7xKXtg2C (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [26] Added token 7i5KKsX2 (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [27] Added token Es9vMFrz (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [28] Added token 4LLbsb5R (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [29] Added token CKaKtYvz (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [30] Added token Taki7fi3 (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [31] Added token hntyVP6Y (decimals=9)
# 2026-06-20 17:38:07 | INFO     | [32] Added token 7ZCm8WBN (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [33] Added token 7vfCXTUX (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [34] Added token AZsHEMXd (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [35] Added token 21rweMLG (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [36] Added token SRMuApVN (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [37] Added token iotEVVZL (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [39] Added token BiDB55p4 (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [40] Added token mb1eu7Tz (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [41] Added token KMNo3nJs (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [42] Added token 5z3EqYQo (decimals=9)
# 2026-06-20 17:38:08 | INFO     | [43] Added token ukHH6c7m (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [44] Added token J1toso1u (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [45] Added token WENWENvq (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [46] Added token 3S8qX1Ms (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [47] Added token 6D7NaB2x (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [48] Added token 8wXtPeU6 (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [49] Added token madHpjRn (decimals=9)
# 2026-06-20 17:38:09 | INFO     | [SETUP] Token setup finished: {'created': 50, 'skipped': 2, 'failed': 0, 'total': 52}
# 2026-06-20 17:38:09 | INFO     | [SETUP] Test wallet inserted: FooAzfN8...
# 2026-06-20 17:38:09 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-20 17:38:09 | WARNING  | [SYNC] Could not fetch token accounts: 'dict' object has no attribute 'encoding'
# 2026-06-20 17:38:09 | INFO     | [SYNC] Wallet 1 sync complete: {'created_assets': 1, 'updated_assets': 0, 'unchanged_assets': 0}
# 2026-06-20 17:38:09 | INFO     | [SETUP] Full development setup completed
# ✅ Setup done!

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
DATABASE_URL = "postgresql+psycopg2://mypguser:m11ay321@localhost:5432/mypgdatabase"
# Create engine with PostgreSQL-specific settings
engine = create_engine( 
    DATABASE_URL,
    echo=True,  # Set to False in production
    pool_size=10,  # Connection pool size
    max_overflow=20  # Max connections beyond pool_size
)

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM token_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-06-20 17:38:23,442 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-06-20 17:38:23 | INFO     | select pg_catalog.version()
# 2026-06-20 17:38:23,443 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-20 17:38:23 | INFO     | [raw sql] {}
# 2026-06-20 17:38:23,444 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-06-20 17:38:23 | INFO     | select current_schema()
# 2026-06-20 17:38:23,445 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-20 17:38:23 | INFO     | [raw sql] {}
# 2026-06-20 17:38:23,446 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-06-20 17:38:23 | INFO     | show standard_conforming_strings
# 2026-06-20 17:38:23,446 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-20 17:38:23 | INFO     | [raw sql] {}
# 2026-06-20 17:38:23,449 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-20 17:38:23 | INFO     | BEGIN (implicit)
# 2026-06-20 17:38:23,450 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-20 17:38:23 | INFO     | SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-20 17:38:23,450 INFO sqlalchemy.engine.Engine [generated in 0.00173s] {'table_name': 'SELECT * FROM token_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-20 17:38:23 | INFO     | [generated in 0.00173s] {'table_name': 'SELECT * FROM token_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-20 17:38:23,453 INFO sqlalchemy.engine.Engine SELECT * FROM token_table
# 2026-06-20 17:38:23 | INFO     | SELECT * FROM token_table
# 2026-06-20 17:38:23,454 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-20 17:38:23 | INFO     | [raw sql] {}
# 2026-06-20 17:38:23,456 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-20 17:38:23 | INFO     | ROLLBACK
#                                                    id tickerSymbol  \
# 0   [b'\x06', b'\x9b', b'\x88', b'W', b'\xfe', b'\...     PLATFORM
# 1   [b'\xc6', b'\xfa', b'z', b'\xf3', b'\xbe', b'\...       STABLE
# 2   [b'\xbf', b'x', b'\x10', b'W', b'C', b'\x14', ...          UNK
# 3   [b'p', b'\xe0', b'N', b'\xcf', b'v', b'\xa2', ...          UNK
# 4   [b'J', b'j', b'?', b'\xa9', b'\x01', b'\x17', ...          UNK
# 5   [b'|', b'\x9b', b'\x8a', b'\xd1', b'e', b'T', ...          UNK
# 6   [b' ', b'L', b'\xc6', b'n', b'\\', b'\xc7', b'...          UNK
# 7   [b'\xcf', b'\xc5', b'1', b'\xaf', b'w', b'\xe2...          UNK
# 8   [b':', b'>', b'r', b'\xb6', b'~', b'\xa9', b'N...          UNK
# 9   [b'\x07', b'\r', b'\x0b', b'\x9b', b'\xee', b'...          UNK
# 10  [b'\x05', b'.', b'\xd3', b'P', b'\x10', b'\xb8...          UNK
# 11  [b'\xab', b'\xf6', b'T', b'=', b'\xc5', b'\x04...          UNK
# 12  [b'\xaa', b'-', b'\x9f', b'=', b'e', b'\r', b'...          UNK
# 13  [b'@', b'r', b'\xd8', b'Q', b'\x93', b'h', b'\...          UNK
# 14  [b'\xf5', b'\xed', b'\xec', b'\x84', b'q', b'\...          UNK
# 15  [b'\x04', b'y', b'\xd9', b'\xc7', b'\xcc', b'\...          UNK
# 16  [b'\x05', b'.', b'\xe1', b'\x83', b'8', b'\x96...          UNK
# 17  [b'\xc5', b'\xf9', b'\xfb', b'2', b'\xf4', b'\...          UNK
# 18  [b'\x0c', b'\xc1', b'\x0f', b'Q', b'j', b'\xaa...          UNK
# 19  [b'\n', b'\xfc', b'\xf8', b'\x96', b'\x8b', b'...          UNK
# 20  [b'i', b"'", b'\xfd', b'\xc0', b'\x1e', b'\xa9...          UNK
# 21  [b'\x08', b'A', b'\xd1', b'\xde', b'\xc7', b'\...          UNK
# 22  [b'7', b'\x99', b'\x8c', b'\xcb', b'\xf2', b'\...          UNK
# 23  [b'\x06', b'\xc1', b'W', b'q', b'T', b'e', b't...          UNK
# 24  [b'[', b'\xe2', b'=', b'|', b'\x88', b'\x1e', ...          UNK
# 25  [b'\x08', b'>', b'\x1d', b']', b'd', b'\xb0', ...          UNK
# 26  [b'g', b'R', b'\x05', b'\\', b' ', b'\xb3', b'...          UNK
# 27  [b'c', b'\xab', b'\xd0', b'\x96', b'p', b'v', ...          UNK
# 28  [b'\xce', b'\x01', b'\x0e', b'`', b'\xaf', b'\...          UNK
# 29  [b'1', b'\x87', b'B', b'd', b'\xbc', b'\xf1', ...          UNK
# 30  [b'\xa8', b'2', b'\xb1', b'4', b'\x7f', b'e', ...          UNK
# 31  [b'\x06', b'\xcf', b'D', b'/', b'\xd1', b'\xea...          UNK
# 32  [b'\n', b's', b' ', b'\x93', b'\x91', b'\x85',...          UNK
# 33  [b'a', b'f', b'\x01', b'g', b'{', b'\x19', b'\...          UNK
# 34  [b'f', b'\xe5', b'\x18', b'\x8a', b'\x13', b'\...          UNK
# 35  [b'\x8e', b'$', b'\x9e', b'\xac', b'*', b'\xa0...          UNK
# 36  [b'\x0f', b'\x14', b'(', b'\x1c', b'C', b'=', ...          UNK
# 37  [b'\x06', b'\x83', b'\x10', b'\x86', b'\x1a', ...          UNK
# 38  [b'\n', b'\xb5', b'\xd3', b'\x06', b'\x1b', b'...          UNK
# 39  [b'\x9f', b'#', b'r', b'{', b'\xb4', b'\xe0', ...          UNK
# 40  [b'\x0b', b'l', b'\x03', b'#', b'|', b'\xe5', ...          UNK
# 41  [b'\x04', b'\xb3', b'~', b'V', b'c', b'\xeb', ...          UNK
# 42  [b'J', b'\x0b', b'b', b'\x8d', b'\xff', b'\x0f...          UNK
# 43  [b'\r', b'\x83', b'#', b'\xc0', b'v', b'\xf0',...          UNK
# 44  [b'\xfc', b'\xd1', b'A', b'\xe9', b'\x83', b',...          UNK
# 45  [b'\x07', b'|', b'\xf6', b':', b'V', b'\xff', ...          UNK
# 46  [b'$', b"'", b'\xc1', b'=', b'\x88', b'w', b'\...          UNK
# 47  [b'M', b'd', b'\x9b', b'\xee', b'N', b'\xdf', ...          UNK
# 48  [b'u', b'\xfa', b'\x18', b'Z', b'\xaf', b'\xf1...          UNK
# 49  [b'\x0b', b'k', b'\x93', b'\x87', b'\xa9', b'\...          UNK
#
#                                       contractAddress           name  \
# 0   [b'\x06', b'\x9b', b'\x88', b'W', b'\xfe', b'\...  Platform Coin
# 1   [b'\xc6', b'\xfa', b'z', b'\xf3', b'\xbe', b'\...    Stable Coin
# 2   [b'\xbf', b'x', b'\x10', b'W', b'C', b'\x14', ...        Unknown
# 3   [b'p', b'\xe0', b'N', b'\xcf', b'v', b'\xa2', ...        Unknown
# 4   [b'J', b'j', b'?', b'\xa9', b'\x01', b'\x17', ...        Unknown
# 5   [b'|', b'\x9b', b'\x8a', b'\xd1', b'e', b'T', ...        Unknown
# 6   [b' ', b'L', b'\xc6', b'n', b'\\', b'\xc7', b'...        Unknown
# 7   [b'\xcf', b'\xc5', b'1', b'\xaf', b'w', b'\xe2...        Unknown
# 8   [b':', b'>', b'r', b'\xb6', b'~', b'\xa9', b'N...        Unknown
# 9   [b'\x07', b'\r', b'\x0b', b'\x9b', b'\xee', b'...        Unknown
# 10  [b'\x05', b'.', b'\xd3', b'P', b'\x10', b'\xb8...        Unknown
# 11  [b'\xab', b'\xf6', b'T', b'=', b'\xc5', b'\x04...        Unknown
# 12  [b'\xaa', b'-', b'\x9f', b'=', b'e', b'\r', b'...        Unknown
# 13  [b'@', b'r', b'\xd8', b'Q', b'\x93', b'h', b'\...        Unknown
# 14  [b'\xf5', b'\xed', b'\xec', b'\x84', b'q', b'\...        Unknown
# 15  [b'\x04', b'y', b'\xd9', b'\xc7', b'\xcc', b'\...        Unknown
# 16  [b'\x05', b'.', b'\xe1', b'\x83', b'8', b'\x96...        Unknown
# 17  [b'\xc5', b'\xf9', b'\xfb', b'2', b'\xf4', b'\...        Unknown
# 18  [b'\x0c', b'\xc1', b'\x0f', b'Q', b'j', b'\xaa...        Unknown
# 19  [b'\n', b'\xfc', b'\xf8', b'\x96', b'\x8b', b'...        Unknown
# 20  [b'i', b"'", b'\xfd', b'\xc0', b'\x1e', b'\xa9...        Unknown
# 21  [b'\x08', b'A', b'\xd1', b'\xde', b'\xc7', b'\...        Unknown
# 22  [b'7', b'\x99', b'\x8c', b'\xcb', b'\xf2', b'\...        Unknown
# 23  [b'\x06', b'\xc1', b'W', b'q', b'T', b'e', b't...        Unknown
# 24  [b'[', b'\xe2', b'=', b'|', b'\x88', b'\x1e', ...        Unknown
# 25  [b'\x08', b'>', b'\x1d', b']', b'd', b'\xb0', ...        Unknown
# 26  [b'g', b'R', b'\x05', b'\\', b' ', b'\xb3', b'...        Unknown
# 27  [b'c', b'\xab', b'\xd0', b'\x96', b'p', b'v', ...        Unknown
# 28  [b'\xce', b'\x01', b'\x0e', b'`', b'\xaf', b'\...        Unknown
# 29  [b'1', b'\x87', b'B', b'd', b'\xbc', b'\xf1', ...        Unknown
# 30  [b'\xa8', b'2', b'\xb1', b'4', b'\x7f', b'e', ...        Unknown
# 31  [b'\x06', b'\xcf', b'D', b'/', b'\xd1', b'\xea...        Unknown
# 32  [b'\n', b's', b' ', b'\x93', b'\x91', b'\x85',...        Unknown
# 33  [b'a', b'f', b'\x01', b'g', b'{', b'\x19', b'\...        Unknown
# 34  [b'f', b'\xe5', b'\x18', b'\x8a', b'\x13', b'\...        Unknown
# 35  [b'\x8e', b'$', b'\x9e', b'\xac', b'*', b'\xa0...        Unknown
# 36  [b'\x0f', b'\x14', b'(', b'\x1c', b'C', b'=', ...        Unknown
# 37  [b'\x06', b'\x83', b'\x10', b'\x86', b'\x1a', ...        Unknown
# 38  [b'\n', b'\xb5', b'\xd3', b'\x06', b'\x1b', b'...        Unknown
# 39  [b'\x9f', b'#', b'r', b'{', b'\xb4', b'\xe0', ...        Unknown
# 40  [b'\x0b', b'l', b'\x03', b'#', b'|', b'\xe5', ...        Unknown
# 41  [b'\x04', b'\xb3', b'~', b'V', b'c', b'\xeb', ...        Unknown
# 42  [b'J', b'\x0b', b'b', b'\x8d', b'\xff', b'\x0f...        Unknown
# 43  [b'\r', b'\x83', b'#', b'\xc0', b'v', b'\xf0',...        Unknown
# 44  [b'\xfc', b'\xd1', b'A', b'\xe9', b'\x83', b',...        Unknown
# 45  [b'\x07', b'|', b'\xf6', b':', b'V', b'\xff', ...        Unknown
# 46  [b'$', b"'", b'\xc1', b'=', b'\x88', b'w', b'\...        Unknown
# 47  [b'M', b'd', b'\x9b', b'\xee', b'N', b'\xdf', ...        Unknown
# 48  [b'u', b'\xfa', b'\x18', b'Z', b'\xaf', b'\xf1...        Unknown
# 49  [b'\x0b', b'k', b'\x93', b'\x87', b'\xa9', b'\...        Unknown
#
#    priceServer exchangeSever  price_tracking stable_coin_official  \
# 0      jupiter       jupiter            True                 None
# 1      jupiter       jupiter            True                 None
# 2      jupiter       jupiter            True                 None
# 3      jupiter       jupiter            True                 None
# 4      jupiter       jupiter            True                 None
# 5      jupiter       jupiter            True                 None
# 6      jupiter       jupiter            True                 None
# 7      jupiter       jupiter            True                 None
# 8      jupiter       jupiter            True                 None
# 9      jupiter       jupiter            True                 None
# 10     jupiter       jupiter            True                 None
# 11     jupiter       jupiter            True                 None
# 12     jupiter       jupiter            True                 None
# 13     jupiter       jupiter            True                 None
# 14     jupiter       jupiter            True                 None
# 15     jupiter       jupiter            True                 None
# 16     jupiter       jupiter            True                 None
# 17     jupiter       jupiter            True                 None
# 18     jupiter       jupiter            True                 None
# 19     jupiter       jupiter            True                 None
# 20     jupiter       jupiter            True                 None
# 21     jupiter       jupiter            True                 None
# 22     jupiter       jupiter            True                 None
# 23     jupiter       jupiter            True                 None
# 24     jupiter       jupiter            True                 None
# 25     jupiter       jupiter            True                 None
# 26     jupiter       jupiter            True                 None
# 27     jupiter       jupiter            True                 None
# 28     jupiter       jupiter            True                 None
# 29     jupiter       jupiter            True                 None
# 30     jupiter       jupiter            True                 None
# 31     jupiter       jupiter            True                 None
# 32     jupiter       jupiter            True                 None
# 33     jupiter       jupiter            True                 None
# 34     jupiter       jupiter            True                 None
# 35     jupiter       jupiter            True                 None
# 36     jupiter       jupiter            True                 None
# 37     jupiter       jupiter            True                 None
# 38     jupiter       jupiter            True                 None
# 39     jupiter       jupiter            True                 None
# 40     jupiter       jupiter            True                 None
# 41     jupiter       jupiter            True                 None
# 42     jupiter       jupiter            True                 None
# 43     jupiter       jupiter            True                 None
# 44     jupiter       jupiter            True                 None
# 45     jupiter       jupiter            True                 None
# 46     jupiter       jupiter            True                 None
# 47     jupiter       jupiter            True                 None
# 48     jupiter       jupiter            True                 None
# 49     jupiter       jupiter            True                 None
#
#    stable_coin_alt  decimals
# 0             None         9
# 1             None         6
# 2             None         9
# 3             None         9
# 4             None         9
# 5             None         9
# 6             None         9
# 7             None         9
# 8             None         9
# 9             None         9
# 10            None         9
# 11            None         9
# 12            None         9
# 13            None         9
# 14            None         9
# 15            None         9
# 16            None         9
# 17            None         9
# 18            None         9
# 19            None         9
# 20            None         9
# 21            None         9
# 22            None         9
# 23            None         9
# 24            None         9
# 25            None         9
# 26            None         9
# 27            None         9
# 28            None         9
# 29            None         9
# 30            None         9
# 31            None         9
# 32            None         9
# 33            None         9
# 34            None         9
# 35            None         9
# 36            None         9
# 37            None         9
# 38            None         9
# 39            None         9
# 40            None         9
# 41            None         9
# 42            None         9
# 43            None         9
# 44            None         9
# 45            None         9
# 46            None         9
# 47            None         9
# 48            None         9
# 49            None         9
