# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
DATABASE_URL = "postgresql+psycopg2://mypguser:m11ay321@localhost:5432/mypgdatabase"
# Create engine with PostgreSQL-specific settings
engine = create_engine( 
    DATABASE_URL,
    echo=True,  # Set to False in production
    pool_size=10,  # Connection pool size
    max_overflow=20  # Max connections beyond pool_size
)

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM token_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-06-29 20:13:12,706 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-06-29 20:13:12 | INFO     | select pg_catalog.version()
# 2026-06-29 20:13:12,708 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:13:12 | INFO     | [raw sql] {}
# 2026-06-29 20:13:12,709 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-06-29 20:13:12 | INFO     | select current_schema()
# 2026-06-29 20:13:12,710 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:13:12 | INFO     | [raw sql] {}
# 2026-06-29 20:13:12,711 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-06-29 20:13:12 | INFO     | show standard_conforming_strings
# 2026-06-29 20:13:12,711 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:13:12 | INFO     | [raw sql] {}
# 2026-06-29 20:13:12,713 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-29 20:13:12 | INFO     | BEGIN (implicit)
# 2026-06-29 20:13:12,714 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:13:12 | INFO     | SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:13:12,715 INFO sqlalchemy.engine.Engine [generated in 0.00164s] {'table_name': 'SELECT * FROM token_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:13:12 | INFO     | [generated in 0.00164s] {'table_name': 'SELECT * FROM token_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:13:12,717 INFO sqlalchemy.engine.Engine SELECT * FROM token_table
# 2026-06-29 20:13:12 | INFO     | SELECT * FROM token_table
# 2026-06-29 20:13:12,718 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:13:12 | INFO     | [raw sql] {}
# 2026-06-29 20:13:12,720 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-29 20:13:12 | INFO     | ROLLBACK
#                                                    id tickerSymbol  \
# 0   [b'\x06', b'\x9b', b'\x88', b'W', b'\xfe', b'\...     PLATFORM
# 1   [b'\xc6', b'\xfa', b'z', b'\xf3', b'\xbe', b'\...       STABLE
# 2   [b'\xbf', b'x', b'\x10', b'W', b'C', b'\x14', ...          UNK
# 3   [b'p', b'\xe0', b'N', b'\xcf', b'v', b'\xa2', ...          UNK
# 4   [b'J', b'j', b'?', b'\xa9', b'\x01', b'\x17', ...          UNK
# 5   [b'|', b'\x9b', b'\x8a', b'\xd1', b'e', b'T', ...          UNK
# 6   [b' ', b'L', b'\xc6', b'n', b'\\', b'\xc7', b'...          UNK
# 7   [b'\xcf', b'\xc5', b'1', b'\xaf', b'w', b'\xe2...          UNK
# 8   [b':', b'>', b'r', b'\xb6', b'~', b'\xa9', b'N...          UNK
# 9   [b'\x07', b'\r', b'\x0b', b'\x9b', b'\xee', b'...          UNK
# 10  [b'\x05', b'.', b'\xd3', b'P', b'\x10', b'\xb8...          UNK
# 11  [b'\xab', b'\xf6', b'T', b'=', b'\xc5', b'\x04...          UNK
# 12  [b'\xaa', b'-', b'\x9f', b'=', b'e', b'\r', b'...          UNK
# 13  [b'@', b'r', b'\xd8', b'Q', b'\x93', b'h', b'\...          UNK
# 14  [b'\xf5', b'\xed', b'\xec', b'\x84', b'q', b'\...          UNK
# 15  [b'\x04', b'y', b'\xd9', b'\xc7', b'\xcc', b'\...          UNK
# 16  [b'\x05', b'.', b'\xe1', b'\x83', b'8', b'\x96...          UNK
# 17  [b'\xc5', b'\xf9', b'\xfb', b'2', b'\xf4', b'\...          UNK
# 18  [b'\x0c', b'\xc1', b'\x0f', b'Q', b'j', b'\xaa...          UNK
# 19  [b'\n', b'\xfc', b'\xf8', b'\x96', b'\x8b', b'...          UNK
# 20  [b'i', b"'", b'\xfd', b'\xc0', b'\x1e', b'\xa9...          UNK
# 21  [b'\x08', b'A', b'\xd1', b'\xde', b'\xc7', b'\...          UNK
# 22  [b'7', b'\x99', b'\x8c', b'\xcb', b'\xf2', b'\...          UNK
# 23  [b'\x06', b'\xc1', b'W', b'q', b'T', b'e', b't...          UNK
# 24  [b'[', b'\xe2', b'=', b'|', b'\x88', b'\x1e', ...          UNK
# 25  [b'\x08', b'>', b'\x1d', b']', b'd', b'\xb0', ...          UNK
# 26  [b'g', b'R', b'\x05', b'\\', b' ', b'\xb3', b'...          UNK
# 27  [b'c', b'\xab', b'\xd0', b'\x96', b'p', b'v', ...          UNK
# 28  [b'\xce', b'\x01', b'\x0e', b'`', b'\xaf', b'\...          UNK
# 29  [b'1', b'\x87', b'B', b'd', b'\xbc', b'\xf1', ...          UNK
# 30  [b'\xa8', b'2', b'\xb1', b'4', b'\x7f', b'e', ...          UNK
# 31  [b'\x06', b'\xcf', b'D', b'/', b'\xd1', b'\xea...          UNK
# 32  [b'\n', b's', b' ', b'\x93', b'\x91', b'\x85',...          UNK
# 33  [b'a', b'f', b'\x01', b'g', b'{', b'\x19', b'\...          UNK
# 34  [b'f', b'\xe5', b'\x18', b'\x8a', b'\x13', b'\...          UNK
# 35  [b'\x8e', b'$', b'\x9e', b'\xac', b'*', b'\xa0...          UNK
# 36  [b'\x0f', b'\x14', b'(', b'\x1c', b'C', b'=', ...          UNK
# 37  [b'\x06', b'\x83', b'\x10', b'\x86', b'\x1a', ...          UNK
# 38  [b'\n', b'\xb5', b'\xd3', b'\x06', b'\x1b', b'...          UNK
# 39  [b'\x9f', b'#', b'r', b'{', b'\xb4', b'\xe0', ...          UNK
# 40  [b'\x0b', b'l', b'\x03', b'#', b'|', b'\xe5', ...          UNK
# 41  [b'\x04', b'\xb3', b'~', b'V', b'c', b'\xeb', ...          UNK
# 42  [b'J', b'\x0b', b'b', b'\x8d', b'\xff', b'\x0f...          UNK
# 43  [b'\r', b'\x83', b'#', b'\xc0', b'v', b'\xf0',...          UNK
# 44  [b'\xfc', b'\xd1', b'A', b'\xe9', b'\x83', b',...          UNK
# 45  [b'\x07', b'|', b'\xf6', b':', b'V', b'\xff', ...          UNK
# 46  [b'$', b"'", b'\xc1', b'=', b'\x88', b'w', b'\...          UNK
# 47  [b'M', b'd', b'\x9b', b'\xee', b'N', b'\xdf', ...          UNK
# 48  [b'u', b'\xfa', b'\x18', b'Z', b'\xaf', b'\xf1...          UNK
# 49  [b'\x0b', b'k', b'\x93', b'\x87', b'\xa9', b'\...          UNK
# 50  [b'G', b'\x9c', b'J', b'\xe1', b't', b'\xe9', ...          UNK
# 51  [b'S', b'R', b'M', b'u', b'A', b'p', b'V', b'N...          UNK
# 52  [b'E', b'P', b'j', b'F', b'W', b'd', b'd', b'5...          UNK
#
#                                       contractAddress           name  \
# 0   [b'\x06', b'\x9b', b'\x88', b'W', b'\xfe', b'\...  Platform Coin
# 1   [b'\xc6', b'\xfa', b'z', b'\xf3', b'\xbe', b'\...    Stable Coin
# 2   [b'\xbf', b'x', b'\x10', b'W', b'C', b'\x14', ...        Unknown
# 3   [b'p', b'\xe0', b'N', b'\xcf', b'v', b'\xa2', ...        Unknown
# 4   [b'J', b'j', b'?', b'\xa9', b'\x01', b'\x17', ...        Unknown
# 5   [b'|', b'\x9b', b'\x8a', b'\xd1', b'e', b'T', ...        Unknown
# 6   [b' ', b'L', b'\xc6', b'n', b'\\', b'\xc7', b'...        Unknown
# 7   [b'\xcf', b'\xc5', b'1', b'\xaf', b'w', b'\xe2...        Unknown
# 8   [b':', b'>', b'r', b'\xb6', b'~', b'\xa9', b'N...        Unknown
# 9   [b'\x07', b'\r', b'\x0b', b'\x9b', b'\xee', b'...        Unknown
# 10  [b'\x05', b'.', b'\xd3', b'P', b'\x10', b'\xb8...        Unknown
# 11  [b'\xab', b'\xf6', b'T', b'=', b'\xc5', b'\x04...        Unknown
# 12  [b'\xaa', b'-', b'\x9f', b'=', b'e', b'\r', b'...        Unknown
# 13  [b'@', b'r', b'\xd8', b'Q', b'\x93', b'h', b'\...        Unknown
# 14  [b'\xf5', b'\xed', b'\xec', b'\x84', b'q', b'\...        Unknown
# 15  [b'\x04', b'y', b'\xd9', b'\xc7', b'\xcc', b'\...        Unknown
# 16  [b'\x05', b'.', b'\xe1', b'\x83', b'8', b'\x96...        Unknown
# 17  [b'\xc5', b'\xf9', b'\xfb', b'2', b'\xf4', b'\...        Unknown
# 18  [b'\x0c', b'\xc1', b'\x0f', b'Q', b'j', b'\xaa...        Unknown
# 19  [b'\n', b'\xfc', b'\xf8', b'\x96', b'\x8b', b'...        Unknown
# 20  [b'i', b"'", b'\xfd', b'\xc0', b'\x1e', b'\xa9...        Unknown
# 21  [b'\x08', b'A', b'\xd1', b'\xde', b'\xc7', b'\...        Unknown
# 22  [b'7', b'\x99', b'\x8c', b'\xcb', b'\xf2', b'\...        Unknown
# 23  [b'\x06', b'\xc1', b'W', b'q', b'T', b'e', b't...        Unknown
# 24  [b'[', b'\xe2', b'=', b'|', b'\x88', b'\x1e', ...        Unknown
# 25  [b'\x08', b'>', b'\x1d', b']', b'd', b'\xb0', ...        Unknown
# 26  [b'g', b'R', b'\x05', b'\\', b' ', b'\xb3', b'...        Unknown
# 27  [b'c', b'\xab', b'\xd0', b'\x96', b'p', b'v', ...        Unknown
# 28  [b'\xce', b'\x01', b'\x0e', b'`', b'\xaf', b'\...        Unknown
# 29  [b'1', b'\x87', b'B', b'd', b'\xbc', b'\xf1', ...        Unknown
# 30  [b'\xa8', b'2', b'\xb1', b'4', b'\x7f', b'e', ...        Unknown
# 31  [b'\x06', b'\xcf', b'D', b'/', b'\xd1', b'\xea...        Unknown
# 32  [b'\n', b's', b' ', b'\x93', b'\x91', b'\x85',...        Unknown
# 33  [b'a', b'f', b'\x01', b'g', b'{', b'\x19', b'\...        Unknown
# 34  [b'f', b'\xe5', b'\x18', b'\x8a', b'\x13', b'\...        Unknown
# 35  [b'\x8e', b'$', b'\x9e', b'\xac', b'*', b'\xa0...        Unknown
# 36  [b'\x0f', b'\x14', b'(', b'\x1c', b'C', b'=', ...        Unknown
# 37  [b'\x06', b'\x83', b'\x10', b'\x86', b'\x1a', ...        Unknown
# 38  [b'\n', b'\xb5', b'\xd3', b'\x06', b'\x1b', b'...        Unknown
# 39  [b'\x9f', b'#', b'r', b'{', b'\xb4', b'\xe0', ...        Unknown
# 40  [b'\x0b', b'l', b'\x03', b'#', b'|', b'\xe5', ...        Unknown
# 41  [b'\x04', b'\xb3', b'~', b'V', b'c', b'\xeb', ...        Unknown
# 42  [b'J', b'\x0b', b'b', b'\x8d', b'\xff', b'\x0f...        Unknown
# 43  [b'\r', b'\x83', b'#', b'\xc0', b'v', b'\xf0',...        Unknown
# 44  [b'\xfc', b'\xd1', b'A', b'\xe9', b'\x83', b',...        Unknown
# 45  [b'\x07', b'|', b'\xf6', b':', b'V', b'\xff', ...        Unknown
# 46  [b'$', b"'", b'\xc1', b'=', b'\x88', b'w', b'\...        Unknown
# 47  [b'M', b'd', b'\x9b', b'\xee', b'N', b'\xdf', ...        Unknown
# 48  [b'u', b'\xfa', b'\x18', b'Z', b'\xaf', b'\xf1...        Unknown
# 49  [b'\x0b', b'k', b'\x93', b'\x87', b'\xa9', b'\...        Unknown
# 50  [b'G', b'\x9c', b'J', b'\xe1', b't', b'\xe9', ...        Unknown
# 51  [b'S', b'R', b'M', b'u', b'A', b'p', b'V', b'N...  Unknown Token
# 52  [b'E', b'P', b'j', b'F', b'W', b'd', b'd', b'5...  Unknown Token
#
#    priceServer exchangeSever  price_tracking stable_coin_official  \
# 0      jupiter       jupiter            True                 None
# 1      jupiter       jupiter            True                 None
# 2      jupiter       jupiter            True                 None
# 3      jupiter       jupiter            True                 None
# 4      jupiter       jupiter            True                 None
# 5      jupiter       jupiter            True                 None
# 6      jupiter       jupiter            True                 None
# 7      jupiter       jupiter            True                 None
# 8      jupiter       jupiter            True                 None
# 9      jupiter       jupiter            True                 None
# 10     jupiter       jupiter            True                 None
# 11     jupiter       jupiter            True                 None
# 12     jupiter       jupiter            True                 None
# 13     jupiter       jupiter            True                 None
# 14     jupiter       jupiter            True                 None
# 15     jupiter       jupiter            True                 None
# 16     jupiter       jupiter            True                 None
# 17     jupiter       jupiter            True                 None
# 18     jupiter       jupiter            True                 None
# 19     jupiter       jupiter            True                 None
# 20     jupiter       jupiter            True                 None
# 21     jupiter       jupiter            True                 None
# 22     jupiter       jupiter            True                 None
# 23     jupiter       jupiter            True                 None
# 24     jupiter       jupiter            True                 None
# 25     jupiter       jupiter            True                 None
# 26     jupiter       jupiter            True                 None
# 27     jupiter       jupiter            True                 None
# 28     jupiter       jupiter            True                 None
# 29     jupiter       jupiter            True                 None
# 30     jupiter       jupiter            True                 None
# 31     jupiter       jupiter            True                 None
# 32     jupiter       jupiter            True                 None
# 33     jupiter       jupiter            True                 None
# 34     jupiter       jupiter            True                 None
# 35     jupiter       jupiter            True                 None
# 36     jupiter       jupiter            True                 None
# 37     jupiter       jupiter            True                 None
# 38     jupiter       jupiter            True                 None
# 39     jupiter       jupiter            True                 None
# 40     jupiter       jupiter            True                 None
# 41     jupiter       jupiter            True                 None
# 42     jupiter       jupiter            True                 None
# 43     jupiter       jupiter            True                 None
# 44     jupiter       jupiter            True                 None
# 45     jupiter       jupiter            True                 None
# 46     jupiter       jupiter            True                 None
# 47     jupiter       jupiter            True                 None
# 48     jupiter       jupiter            True                 None
# 49     jupiter       jupiter            True                 None
# 50     jupiter       jupiter            True                 None
# 51     jupiter       jupiter           False                 None
# 52     jupiter       jupiter           False                 None
#
#    stable_coin_alt  decimals
# 0             None         9
# 1             None         6
# 2             None         6
# 3             None         8
# 4             None         6
# 5             None         6
# 6             None         6
# 7             None         8
# 8             None         9
# 9             None         9
# 10            None         6
# 11            None         8
# 12            None         6
# 13            None         6
# 14            None         6
# 15            None         6
# 16            None         5
# 17            None         6
# 18            None         8
# 19            None         9
# 20            None         6
# 21            None         6
# 22            None         6
# 23            None         9
# 24            None         9
# 25            None         6
# 26            None         9
# 27            None         9
# 28            None         6
# 29            None         6
# 30            None         9
# 31            None         9
# 32            None         8
# 33            None         4
# 34            None         8
# 35            None         5
# 36            None         6
# 37            None         6
# 38            None         6
# 39            None         9
# 40            None         6
# 41            None         6
# 42            None         9
# 43            None         6
# 44            None         9
# 45            None         5
# 46            None         6
# 47            None         6
# 48            None         9
# 49            None         6
# 50            None         6
# 51            None         6
# 52            None         6

# %%
from dev_setup import reconcile_onchain_to_securities

result = reconcile_onchain_to_securities(wallet_pk=1)   # ← change to your wallet id

if result.is_ok():
    print("✅ Reconciliation done!")
    print(result.ok_value)           # ← changed from result.value
else:
    print("❌ Error:", result.err_value)   # ← changed from result.error
# Out:
# 2026-06-29 16:18:39 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 16:18:39 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 16:18:39 | INFO     | [SYNC] Wallet 1 sync complete: {'created_assets': 0, 'updated_assets': 0}
# 2026-06-29 16:18:39 | INFO     | [RECONCILE] Reconciliation complete for wallet 1: {'assets_processed': 2, 'securities_created': 1, 'securities_updated': 0, 'unknown_tokens_added': 0, 'unknown_tokens_failed': 0}
# [DEBUG] Found 1 token accounts for this wallet
# [DEBUG] [0] Found token: EPjFWdd5... amount=9680000
#
# [DEBUG] Final summary: {'created_assets': 0, 'updated_assets': 0}
# ✅ Reconciliation done!
# {'assets_processed': 2, 'securities_created': 1, 'securities_updated': 0, 'unknown_tokens_added': 0, 'unknown_tokens_failed': 0}

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM security_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-06-29 20:05:39,275 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-06-29 20:05:39 | INFO     | select pg_catalog.version()
# 2026-06-29 20:05:39,276 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:05:39 | INFO     | [raw sql] {}
# 2026-06-29 20:05:39,277 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-06-29 20:05:39 | INFO     | select current_schema()
# 2026-06-29 20:05:39,278 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:05:39 | INFO     | [raw sql] {}
# 2026-06-29 20:05:39,279 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-06-29 20:05:39 | INFO     | show standard_conforming_strings
# 2026-06-29 20:05:39,279 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:05:39 | INFO     | [raw sql] {}
# 2026-06-29 20:05:39,282 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-29 20:05:39 | INFO     | BEGIN (implicit)
# 2026-06-29 20:05:39,283 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:05:39 | INFO     | SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:05:39,283 INFO sqlalchemy.engine.Engine [generated in 0.00161s] {'table_name': 'SELECT * FROM security_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:05:39 | INFO     | [generated in 0.00161s] {'table_name': 'SELECT * FROM security_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:05:39,285 INFO sqlalchemy.engine.Engine SELECT * FROM security_table
# 2026-06-29 20:05:39 | INFO     | SELECT * FROM security_table
# 2026-06-29 20:05:39,285 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:05:39 | INFO     | [raw sql] {}
# 2026-06-29 20:05:39,288 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-29 20:05:39 | INFO     | ROLLBACK
#    id  parent_id    amount  purchase_price_usdc sale_price_usdc  \
# 0   1          1         0                  0.0            None
# 1   3          1  62939590                  0.0            None
# 2   2          2         0                  0.0            None
#
#    purchase_time_ms sale_time_ms  buy_fee_native_lamports  buy_fee_usdc  \
# 0     1782773369806         None                        0           0.0
# 1     1782776863542         None                        0           0.0
# 2     1782775119690         None                        0           0.0
#
#   sell_fee_native_lamports sell_fee_usdc revenue_at_sale_usdc  isClosed  \
# 0                     None          None                 None      True
# 1                     None          None                 None     False
# 2                     None          None                 None      True
#
#                 buy_tx_id sell_tx_id  isTax  isSavings  isGas
# 0  reconcile_1_1782773369       None  False       True  False
# 1  move_to_gas_1782776863       None  False      False   True
# 2  reconcile_1_1782775119       None  False       True  False

# %%
# read table data using sql query

# Show every row
pd.set_option('display.max_rows', None)

# Show every column (optional but helpful)
pd.set_option('display.max_columns', None)
sql_df = pd.read_sql(
    "SELECT * FROM investment_table",
    con=engine
)

print(sql_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # read table data using sql query
#       2
#       3 # Show every row
# ----> 4 pd.set_option('display.max_rows', None)
#       5
#       6 # Show every column (optional but helpful)
#       7 pd.set_option('display.max_columns', None)
#
# NameError: name 'pd' is not defined

# %%
from sqlalchemy.orm import sessionmaker
from db_manager_v2 import sync_wallet_balances, engine

# Create a session
Session = sessionmaker(bind=engine)
session = Session()

# Run the sync (change wallet_pk to your actual wallet id)
result = sync_wallet_balances(session=session, wallet_pk=1)

# Print the result
if result.is_ok():
    print("✅ Sync completed successfully!")
    print(result.ok_value)
else:
    print("❌ Sync failed:")
    print(result.err_value)

session.close()
# Out:
# 2026-06-29 18:36:57 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 18:36:57 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 18:36:57 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 18:36:57 | INFO     | [SYNC] Wallet 1 sync complete: {'created_assets': 1, 'updated_assets': 2}
# [DEBUG] Found 2 token accounts for this wallet
# [DEBUG] [0] Found token: SRMuApVN... amount=670720930
# [DEBUG] [0] Token SRMuApVN not in database - trying to add it...
# [DEBUG] [0] Successfully added unknown token: SRMuApVN
# [DEBUG] [0] Created NEW Asset for token: SRMuApVN
# [DEBUG] [1] Found token: EPjFWdd5... amount=5614400
# [DEBUG] [1] Updated existing Asset for EPjFWdd5
#
# [DEBUG] Final summary: {'created_assets': 1, 'updated_assets': 2}
# ✅ Sync completed successfully!
# {'created_assets': 1, 'updated_assets': 2}

# %%
from db_manager_v2 import repair_investment_from_tx
from sqlalchemy.orm import sessionmaker
from db_manager_v2 import sync_wallet_balances, engine
import logging
from logging_config import setup_logging
setup_logging(log_file="trades.log")

# Create a session
Session = sessionmaker(bind=engine)
session = Session()

result = repair_investment_from_tx(
    session=session,                    # ← Pass the session
    investment_id=7,
    tx_signature="4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4",
    sold_lamports=96800
)

print(result)
logging.info(result)
# Out:
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | [REPAIR] Repaired Investment 7 | sold=96800, remaining=9196000, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# 2026-06-29 19:21:54 | INFO     | Ok(True)
# Ok(True)

# %%
from db_manager_v2 import get_open_investments

result = get_open_investments(session=session, wallet_pk=1)
print(result)
# Out:
# Ok([{'investment_id': 8, 'amount_lamports': 9196000, 'purchase_price_usdc': 0.0, 'purchase_time_ms': 1782777027052, 'buy_tx_id': 'allocate_from_security_2'}])

# %%
from db_manager_v2 import get_jupiter_swap_details

result = get_jupiter_swap_details("4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4")
print(result)
# Out:
# 2026-06-29 19:41:17 | INFO     | Logging initialized. Writing to logs/trades.log
# Ok({'signature': '4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4', 'slot': 429784020, 'block_time': 1782784328, 'user_wallet': 'JCDgrYTDUiRPPyLCpkoishE7DHvLJVqadzDoAuQNsazF', 'token_changes': {'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v': -96800, 'SRMuApVNdxXokk5GT7XD5cUUgXMBCoAz2LHeuAoKWRt': 15965307}, 'success': True})

# %%
from db_manager_v2 import recover_trade_from_tx
from sqlalchemy.orm import sessionmaker
from db_manager_v2 import engine

Session = sessionmaker(bind=engine)
session = Session()
result = recover_trade_from_tx(
    tx_signature="4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4",
    wallet_pk=1
)

print(result)
# Out:
# 2026-06-29 19:47:48 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 19:47:48 | INFO     | [REPAIR] Repaired Investment 8 | sold=96800, remaining=9099200, tx=4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4
# Ok({'status': 'recovered', 'investment_id': 8, 'tx_signature': '4XmoCCueudt2GGwxVgVAXAHmWsnHGtejLCRPDPQGe4NwoxhrkJfDp28BqJjgJ61ZyPkygQNcxF2K2ndMixG1WGN4', 'sold_lamports': 96800, 'sold_mint': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v'})

# %%
from db_manager_v2 import recover_trade_from_tx
from sqlalchemy.orm import sessionmaker
from db_manager_v2 import engine

Session = sessionmaker(bind=engine)
session = Session()
result = recover_trade_from_tx(
    tx_signature="",
    wallet_pk=1
)

print(result)

# %%
from db_manager_v2 import get_recent_swap_signatures, recover_trade_from_tx
sigs = get_recent_swap_signatures(wallet_pk=1, limit=30)

for sig in sigs.ok_value:
    result = recover_trade_from_tx(tx_signature=sig, wallet_pk=1)
    print(result)
# Out:
# 2026-06-29 20:05:11 | INFO     | Logging initialized. Writing to logs/trades.log
# 2026-06-29 20:05:11 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# 2026-06-29 20:05:11 | INFO     | [RPC] Using PRIMARY: https://mainnet.helius-rpc.com/
# 2026-06-29 20:05:11 | INFO     | HTTP Request: POST https://mainnet.helius-rpc.com/?api-key=c0dcc617-ab44-4343-8eb6-9cb7ca174243 "HTTP/1.1 200 OK"
# Ok({'status': 'already_recorded', 'investment_id': 7, 'message': 'This transaction was already recorded'})
# Ok({'status': 'already_recorded', 'investment_id': 6, 'message': 'This transaction was already recorded'})
# Ok({'status': 'already_recorded', 'investment_id': 5, 'message': 'This transaction was already recorded'})
# Ok({'status': 'already_recorded', 'investment_id': 4, 'message': 'This transaction was already recorded'})
# Err('No token changes found')
# Ok({'status': 'already_recorded', 'investment_id': 1, 'message': 'This transaction was already recorded'})
# Err('Cannot sell more than available (9099200 lamports)')
# Err('No token changes found')

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM asset_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-06-29 20:06:04,527 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-29 20:06:04 | INFO     | BEGIN (implicit)
# 2026-06-29 20:06:04,528 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:06:04 | INFO     | SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-29 20:06:04,529 INFO sqlalchemy.engine.Engine [cached since 25.25s ago] {'table_name': 'SELECT * FROM asset_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:06:04 | INFO     | [cached since 25.25s ago] {'table_name': 'SELECT * FROM asset_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-29 20:06:04,530 INFO sqlalchemy.engine.Engine SELECT * FROM asset_table
# 2026-06-29 20:06:04 | INFO     | SELECT * FROM asset_table
# 2026-06-29 20:06:04,531 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-29 20:06:04 | INFO     | [raw sql] {}
# 2026-06-29 20:06:04,533 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-29 20:06:04 | INFO     | ROLLBACK
#    id  wallet                                               coin  \
# 0   1       1  [b'\x06', b'\x9b', b'\x88', b'W', b'\xfe', b'\...
# 1   3       1  [b'S', b'R', b'M', b'u', b'A', b'p', b'V', b'N...
# 2   2       1  [b'E', b'P', b'j', b'F', b'W', b'd', b'd', b'5...
#
#    audited_amount_sum_lamports  audited_time_unix_ms  isNative  \
# 0                     60395311         1782783417595      True
# 1                    670720930         1782783417821     False
# 2                      5614400         1782783417823     False
#
#   isOfficialStable isAltStable
# 0             None        None
# 1             None        None
# 2             None        None
