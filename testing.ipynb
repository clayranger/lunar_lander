# %% [markdown]
# <h1>LUNAR LANDER ALPHA 0.01</h1>
# <h3>Copyright 2019-2026 Matthew Clay</h3>
# <h2>Private and Confidential.</h2>

# %% [markdown]
# <h2>plans for 0.02
# <br>
# drop</h2>

# %%
from lunar_lander import *
import db_manager as terminal
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
DATABASE_URL = "postgresql+psycopg2://mypguser:m11ay321@localhost:5432/mypgdatabase"
# Create engine with PostgreSQL-specific settings
engine = create_engine( 
    DATABASE_URL,
    echo=True,  # Set to False in production
    pool_size=10,  # Connection pool size
    max_overflow=20  # Max connections beyond pool_size
)

# %% [markdown]
# <h3>Greet the Lunar Lander</h3>

# %%
hello()
# Out:
# hello world
# lunar lander 0.1 alpha
# copyright 2020-2026 Matthew Clay. Private and confidential.

# %% [markdown]
# <h3>connect to database</h3>

# %%
DATABASE_URL = "postgresql+psycopg2://mypguser:m11ay321@localhost:5432/mypgdatabase"

# Create engine with PostgreSQL-specific settings
engine = create_engine(
    DATABASE_URL,
    echo=True,  # Set to False in production
    pool_size=10,  # Connection pool size
    max_overflow=20  # Max connections beyond pool_size
)
engine
# Out:
# Engine(postgresql+psycopg2://mypguser:***@localhost:5432/mypgdatabase)

# %%
thing = terminal.get_token_key("")
# how do i unwrap the thing lol
thing
# Out:
# Result(value=None, error=Error(message='given_key cannot be empty or None', code=None, details=None))

# %%
rosebud()
# Out:
# 2026-06-16 07:52:52,308 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-16 07:52:52,309 INFO sqlalchemy.engine.Engine SELECT EXISTS (SELECT 1
# FROM token_table
# WHERE token_table.id = CAST(%(param_1)s AS BYTEA)) AS anon_1
# 2026-06-16 07:52:52,309 INFO sqlalchemy.engine.Engine [cached since 959.1s ago] {'param_1': <psycopg2.extensions.Binary object at 0x74a4e7636130>}
# stable coin in db -> proceeding with transaction
# 2026-06-16 07:52:52,311 INFO sqlalchemy.engine.Engine SELECT EXISTS (SELECT 1
# FROM token_table
# WHERE token_table.id = CAST(%(param_1)s AS BYTEA)) AS anon_1
# 2026-06-16 07:52:52,311 INFO sqlalchemy.engine.Engine [cached since 959.1s ago] {'param_1': <psycopg2.extensions.Binary object at 0x74a4e710a1c0>}
# platform coin in db -> proceeding with transaction
# 2026-06-16 07:52:52,313 INFO sqlalchemy.engine.Engine SELECT wallet_table.id
# FROM wallet_table
#  LIMIT %(param_1)s
# ...

# %%
with terminal.get_session(terminal.engine) as session:
    thing = is_number_wallets_1(session)
    if thing.is_error:
        print("its a fucking error")
        print(thing)
    else:
        print("she good")
        print(thing)
# Out:
# 2026-06-15 22:29:39,260 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-06-15 22:29:39,260 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-15 22:29:39,261 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-06-15 22:29:39,262 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-15 22:29:39,263 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-06-15 22:29:39,263 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-15 22:29:39,264 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 22:29:39,266 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM wallet_table
# 2026-06-15 22:29:39,266 INFO sqlalchemy.engine.Engine [generated in 0.00092s] {}
# she good
# Result(value=True, error=None)
# 2026-06-15 22:29:39,268 INFO sqlalchemy.engine.Engine COMMIT

# %%
data = {
    "amount": 1_000_000_000,           # 1 SOL in lamports
    "purchase_price_usdc": 142.50,
    "purchase_time_ms": 1718450000000,
    "buy_fee_native_lamports": 5000,
    "buy_fee_usdc": 0.01,
    "buy_tx_id": "5xK9...abc123"
}

with terminal.get_session(terminal.engine) as session:
    token_key = get_token_key(WORLD_STABLE_COIN).value
    print("world stable is " + WORLD_STABLE_COIN)
    thing = insert_investment(session, token_key, InvestmentCreate(**data))
    if thing.is_error:
        print("its a fucking error")
        print(thing)
    else:
        print("she good")
        print(thing)
# Out:
# world stable is EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# 2026-06-15 22:29:40,674 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 22:29:40,687 INFO sqlalchemy.engine.Engine SELECT wallet_table.id
# FROM wallet_table
#  LIMIT %(param_1)s
# 2026-06-15 22:29:40,687 INFO sqlalchemy.engine.Engine [generated in 0.00067s] {'param_1': 2}
# 2026-06-15 22:29:40,690 INFO sqlalchemy.engine.Engine SELECT EXISTS (SELECT 1
# FROM asset_table
# WHERE asset_table.coin = CAST(%(param_1)s AS BYTEA)) AS anon_1
# 2026-06-15 22:29:40,691 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {'param_1': <psycopg2.extensions.Binary object at 0x70b6583db8a0>}
# native is here. nothing to do but get the id handle
# 2026-06-15 22:29:40,693 INFO sqlalchemy.engine.Engine SELECT asset_table.id, asset_table.wallet, asset_table.coin, asset_table.audited_amount_sum_lamports, asset_table.audited_time_unix_ms, asset_table."isNative", asset_table."isOfficialStable", asset_table."isAltStable"
# ...

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM investment_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-06-16 07:53:00,490 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-16 07:53:00,491 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-06-16 07:53:00,492 INFO sqlalchemy.engine.Engine [cached since 46.52s ago] {'table_name': 'SELECT * FROM investment_table', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-06-16 07:53:00,493 INFO sqlalchemy.engine.Engine SELECT * FROM investment_table
# 2026-06-16 07:53:00,493 INFO sqlalchemy.engine.Engine [raw sql] {}
# ...

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM security_table",
    con=engine
)

print(sql_df)

# %%
# read table data using sql query
sql_df = pd.read_sql(
    "SELECT * FROM asset_table",
    con=engine
)

print(sql_df)
# Out:
# 2026-05-31 13:18:32,525 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-05-31 13:18:32,526 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-31 13:18:32,527 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-05-31 13:18:32,527 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-31 13:18:32,528 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-05-31 13:18:32,528 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-31 13:18:32,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-31 13:18:32,531 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...

# %% [markdown]
# <h3>I want to create a virtual trade, then I want to create the structrue to legally handle that trade. </h3>
# <h4>Structure: taxes, records, autowitholding or whatever.</h4>

# %% [markdown]
# <h4>question? will i only have 1 wallet? how will I be handling wallets</h4>
# <h5>we will act if there is only one wallet in system</h5>

# %% [markdown]
# <h4>so we have testing_random_buy()
#     <br> this will be on top of my first production ready functions to make a real trade and record tax info
# </h4>

# %% [markdown]
# <h3>so i think I should focus on extreme reuse of code being that I want the code to be production clean
# <br>
# so for like my databases, every query can be a python function in my database code page</h3>

# %% [markdown]
# <h2>
#     So i dunno. Like why would i need a clean frontend for insert investment?
# </h2>
